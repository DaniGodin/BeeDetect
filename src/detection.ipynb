# %%
import numpy as np
import imageio

# %% [markdown]
# # BEE DETECT

# %%
img = imageio.imread('../TEST/01_inf.jpg')
img.shape, im_ski.dtype
# Out:
# ((1536, 2048, 3), dtype('uint8'))

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
